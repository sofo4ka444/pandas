# %% [markdown]
# # Семинар 1

# %% [markdown]
# ## pandas

# %% [markdown]
# ![](pandas.jpg)

# %% [markdown]
# - документация: http://pandas.pydata.org/pandas-docs/stable/
# - 10 minutes to pandas: https://pandas.pydata.org/pandas-docs/stable/10min.html
# - Pandas Tutorial: DataFrames in Python: https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python
# - Cheet Sheet: https://www.analyticsvidhya.com/blog/2015/07/11-steps-perform-data-analysis-pandas-python/
# - Visualization: http://pandas.pydata.org/pandas-docs/stable/visualization.html

# %% [markdown]
# Будем работать с данными, собранными благодаря опросу студентов математического курса средней школы в Португалии (возраст - от 15 до 22 лет). Они находятся в файле "math_students.csv". Целевой переменной является итоговая оценка студента за курс.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# магическая функция, позволяющая выводить графики прямо в ноутбук
# %matplotlib inline

# %% [markdown]
# Загрузим данные и посмотрим на них.

# %%
# если данные и ноутбук находятся в разных папках, то для загрузки файла помимо названия необходимо также прописать путь к нему
# .csv - текстовый файл для представления табличных данных, разделенных каким-то символом. В данном случае - запятой
data = pd.read_csv('math_students.csv', delimiter=',')

# функция .head(n) выводит первые n строк таблицы (по умолчанию n=5)
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Аналогично, можно смотреть не на верхние строки таблицы, а на нижние:

# %%
data.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# В данном случае объектами являются студенты, признаками - различные их характеристики. Найдем число и тех, и других:

# %%
data.shape
# Out:
# (395, 33)

# %% [markdown]
# Итак, всего объектов 395, а признаков - 32 (учитываем, что один из столбцов - это целевая переменная). Все признаки имеют разную природу. Вот их более подробная расшифровка:
#
#  - school - тип школы ("GP" - Gabriel Pereira или "MS" - Mousinho da Silveira)
#  - sex - пол ("F" - female или "M" - male)
#  - age - возраст (от 15 до 22)
#  - address - откуда студент ("U" - urban или "R" - rural)
#  - famsize - размер семьи ("LE3" - меньше или равно 3 или "GT3" - больше 3)
#  - Pstatus - в каких отношениях родители ("T" - живут вместе "A" - раздельно)
#  - Medu - образование матери (0 - никакого,  1 - начальное образование (4 класса), 2 – от 5 до 9 классов, 3 – среднеспециальное или 4 – высшее)
#  - Fedu - образование отца (0 - никакого,  1 - начальное образование (4 класса), 2 – от 5 до 9 классов, 3 – среднеспециальное или 4 – высшее)
#  - Mjob - работа матери ("teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#  - Fjob - работа отца ("teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#  - reason - причина выбора школы (близко к дому — "home", репутация школы — "reputation", предпочтение некоторым предметам - "course" или "other")
#  - guardian - опекун ("mother", "father" или "other")
#  - traveltime - время от дома до школы (1 - меньше 15 мин., 2 - 15 до 30 мин., 3 - 30 мин. до 1 часа, или 4 - больше 1 часа)
#  - studytime - количество часов обучения в неделю (1 - меньше 2 часов, 2 - от 2 до 5 часов, 3 - от 5 до 10 часов, или 4 - больше 10 часов)
#  - failures - количество ранее не сданных предметов (n if 1 <= n < 3, else 4)
#  - schoolsup - дополнительные занятия (yes or no)
#  - famsup - помощь от семьи при выполнении заданий (yes or no)
#  - paid - дополнительные платные занятия (yes or no)
#  - activities - внеклассная деятельность (yes or no)
#  - nursery - посещал детский сад (yes or no)
#  - higher - желание высшего образования (yes or no)
#  - internet - домашний интернет (yes or no)
#  - romantic - состоит в романтических отношениях (yes or no)
#  - famrel - насколько хороши отношения в семье (от 1 - очень плохие до 5 - превосходные)
#  - freetime - наличие свободного времени после школы (от 1 - очень мало до 5 - очень много)
#  - goout - гуляет с друзьями (от 1 - редко до 5 - очень часто)
#  - Dalc - употребление алкоголя в будние дни (от 1 - очень редко до 5 - очень часто)
#  - Walc - употребление алкоголя в выходные (от 1 - очень редко до 5 - очень часто)
#  - health - текущее состояние здоровья (от 1 - очень плохое до 5 - очень хорошее)
#  - absences - количество школьных пропусков (от 0 до 93)
#  - G1 - оценка за первый семестр (от 0 до 20)
#  - G2 - оценка за второй семестр (от 0 до 20)
#  - G3 - итоговая оценка (от 0 до 20)

# %% [markdown]
# Для вывода названий всех признаков есть специальная функция:

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# Чтобы отделить от признаков целевую переменную, давайте удалим из таблицы последнюю колонку - 'G3'. Как получить таблицу без последней колонки?

# %%
data[:, :-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(None, -1, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-7-d39eb4356b7c> in <cell line: 1>()
# ----> 1 data[:, :-1]
#
# ...

# %% [markdown]
# Как видно, индексация как в массивах `numpy` в нашем случае не работает. Давайте рассмотрим список названий колонок, который упоминался выше, без последнего элемента:

# %%
data.columns[:-1]
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2'],
#       dtype='object')

# %% [markdown]
# Теперь "выделим" в таблице те столбцы, которые мы хотим оставить.

# %%
data[data.columns[:-1]].head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   romantic famrel  freetime  goout  Dalc Walc health absences  G1  G2
# 0       no      4         3      4     1    1      3        6   5   6
# 1       no      5         3      3     1    1      3        4   5   5
# 2       no      4         3      2     2    3      3       10   7   8
# 3      yes      3         2      2     1    1      5        2  15  14
# 4       no      4         3      2     1    2      5        4   6  10
#
# [5 rows x 32 columns]

# %% [markdown]
# Заметим, что если бы мы выделили все названия исходных столбцов, то у нас получилась бы и исходная таблица:

# %%
data[data.columns].head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Как можно еще? Можно оставить элементы таблицы с нужными индексами с помощью функции `iloc`. Все строки мы оставляем на своих местах (`:`), а столбцы берем до минус первого - последнего (`:-1`):

# %%
data.iloc[:, :-1].head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   romantic famrel  freetime  goout  Dalc Walc health absences  G1  G2
# 0       no      4         3      4     1    1      3        6   5   6
# 1       no      5         3      3     1    1      3        4   5   5
# 2       no      4         3      2     2    3      3       10   7   8
# 3      yes      3         2      2     1    1      5        2  15  14
# 4       no      4         3      2     1    2      5        4   6  10
#
# [5 rows x 32 columns]

# %% [markdown]
# Также можно обращаться к строкам-столбцам таблицы не по индексам, а по названиям - с помощью функции `loc`:

# %%
data.loc[:, data.columns[:-1]].head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   romantic famrel  freetime  goout  Dalc Walc health absences  G1  G2
# 0       no      4         3      4     1    1      3        6   5   6
# 1       no      5         3      3     1    1      3        4   5   5
# 2       no      4         3      2     2    3      3       10   7   8
# 3      yes      3         2      2     1    1      5        2  15  14
# 4       no      4         3      2     1    2      5        4   6  10
#
# [5 rows x 32 columns]

# %% [markdown]
# Еще один способ - исключим из таблицы все, что нам нужно, с помощью функции `drop`:

# %%
data.drop(['G3'], axis=1).head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   romantic famrel  freetime  goout  Dalc Walc health absences  G1  G2
# 0       no      4         3      4     1    1      3        6   5   6
# 1       no      5         3      3     1    1      3        4   5   5
# 2       no      4         3      2     2    3      3       10   7   8
# 3      yes      3         2      2     1    1      5        2  15  14
# 4       no      4         3      2     1    2      5        4   6  10
#
# [5 rows x 32 columns]

# %% [markdown]
# Этот способ достаточно удобен, потому что он не зависит от положения колонки "G3" в таблице - неважно, была она последней, первой или третьей с конца.

# %% [markdown]
# Обратите внимание на важный параметр `axis`, который указывает на то, на что нужно смотреть - на колонки или столбцы. По умолчанию в данном случае он принимает значение 0 - посмотрим, что получится, если забыть его:

# %%
data.drop(['G3'], axis=0).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-2de82ff85aa4> in <cell line: 1>()
# ----> 1 data.drop(['G3'], axis=0).head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %% [markdown]
# Действительно, никакая из строк таблицы не называется "G3", так что программа не понимает, что мы от нее хотим - исключать нечего.

# %% [markdown]
# Посмотрим, есть ли в данных пропуски:

# %%
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# Давайте разберемся, что сейчас произошло.

# %%
data.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 390   False  False  False    False    False    False  False  False  False
# 391   False  False  False    False    False    False  False  False  False
# 392   False  False  False    False    False    False  False  False  False
# 393   False  False  False    False    False    False  False  False  False
# 394   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences  \
# ...

# %%
data.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# Итак, пропусков нет.

# %% [markdown]
# По любой функции можно получить информацию из документации следующим образом:

# %%
# ?pd.isnull()
# Out:
# Object `pd.isnull()` not found.

# %% [markdown]
# Либо - нажав Shift+Tab+Tab.

# %% [markdown]
# Можно вывести статистику по значениям признаков:

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# Более подробное описание значений признаков (количество непустых значений, типов столбцов и объема занимаемой памяти):

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# Какие значения принимает признак `guardian`?

# %%
data['guardian'].unique()
# Out:
# array(['mother', 'father', 'other'], dtype=object)

# %%
data['guardian'].nunique()
# Out:
# 3

# %%
data['guardian'].value_counts()
# Out:
# mother    273
# father     90
# other      32
# Name: guardian, dtype: int64

# %% [markdown]
# Выделим только тех студентов, у которых опекуном является мать и которая работает учителем или на дому:

# %%
data[(data['guardian'] == 'mother') & ((data['Mjob'] == 'teacher') | (data['Mjob'] == 'at_home'))].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0      GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 2      GP   F   15       U     LE3       T     1     1  at_home    other  ...
# 10     GP   F   15       U     GT3       T     4     4  teacher   health  ...
# 13     GP   M   15       U     GT3       T     4     3  teacher    other  ...
# 20     GP   M   15       U     GT3       T     4     3  teacher    other  ...
#
#    famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0       4        3      4     1     1      3        6   5   6   6
# 2       4        3      2     2     3      3       10   7   8  10
# 10      3        3      3     1     2      2        0  10   8   9
# 13      5        4      3     1     2      3        2  10  10  11
# 20      4        4      1     1     1      1        0  13  14  15
#
# [5 rows x 33 columns]

# %% [markdown]
# Работа с признаками - очень важный этап решения задачи. Помимо имеющихся признаков, можно создавать новые, которые могут оказаться полезными для построения качественного алгоритма. Например, внимательно изучив описания признаков, связанных с алкоголем, создадим признак "alc", который будет отражать общее употребление алкоголя в течение недели по формуле ниже:
#
# $$
# alc = \frac{5\times Dalc + 2 \times Walc}{7}
# $$

# %%
data['alc'] = (5 * data['Dalc'] + 2 * data['Walc']) / 7

# %%
data[['Walc', 'Dalc', 'alc']].head()
# Out:
#    Walc  Dalc       alc
# 0     1     1  1.000000
# 1     1     1  1.000000
# 2     3     2  2.285714
# 3     1     1  1.000000
# 4     2     1  1.285714

# %% [markdown]
# Проанализируем взаимосвязь количества пропусков и успехов в учебе. Посмотрим на распределение количества пропусков у студентов:

# %%
plt.figure(figsize=(10,7))
plt.title('Absences distribution')
data['absences'].hist()
plt.xlabel('absences')
plt.ylabel('number of students')
plt.show()

# %% [markdown]
# Посмотрим на среднее количество пропусков:

# %%
data['absences'].mean()
# Out:
# 5.708860759493671

# %% [markdown]
# Итак, из гистограммы и полученного значения можно сделать вывод, что большинство студентов пропускает не так много занятий. Теперь посмотрим на влияние количества пропусков на итоговую оценку. Для этого разделим студентов на две части: те, у кого количество пропусков меньше среднего, и те, у кого оно не меньше среднего.

# %%
mean_absences = data['absences'].mean()
stud_few_absences = data[data['absences'] < mean_absences]
stud_many_absences = data[data['absences'] >= mean_absences]

# %% [markdown]
# Посмотрим, сколько получилось и тех, и других.

# %%
print('Students with few absences:', stud_few_absences.shape[0])
print('Students with many absences:', stud_many_absences.shape[0])
# Out:
# Students with few absences: 249
# Students with many absences: 146

# %% [markdown]
# Посчитаем среднее значение целевой переменной для каждой части.

# %%
stud_few_absences_g3 = stud_few_absences['G3'].mean()
stud_many_absences_g3 = stud_many_absences['G3'].mean()
print('Students with few absences, mean G3:', stud_few_absences_g3)
print('Students with many absences, mean G3:', stud_many_absences_g3)
# Out:
# Students with few absences, mean G3: 10.168674698795181
# Students with many absences, mean G3: 10.835616438356164

# %% [markdown]
# Итак, средние оценки примерно одинаковы - у тех, кто пропускал меньше занятий, она чуть хуже. Возможно, студенты, пропускавшие много занятий, знали материал очень хорошо :) Впрочем, подобное исследование не позволяет делать никаких серьезных выводов.

# %% [markdown]
# Также данные можно исследовать с помощью группировки и агрегирования. Например, найдем исследуем закономерности, связанные с разными школами. Сгруппируем объекты по школам:

# %%
data_by_school = data.groupby('school')
data_by_school.describe()
# Out:
#           age                                                       Medu  \
#         count       mean       std   min    25%   50%   75%   max  count
# school
# GP      349.0  16.521490  1.216610  15.0  16.00  16.0  17.0  22.0  349.0
# MS       46.0  18.021739  0.881643  17.0  17.25  18.0  18.0  21.0   46.0
#
#                   ...     G3          alc                                     \
#             mean  ...    75%   max  count      mean       std  min       25%
# school            ...
# GP      2.802292  ...  14.00  20.0  349.0  1.677446  0.903404  1.0  1.000000
# MS      2.347826  ...  12.75  19.0   46.0  1.978261  0.995667  1.0  1.285714
#
#
#              50%  75%  max
# school
# GP      1.285714  2.0  5.0
# MS      1.571429  2.5  5.0
#
# [2 rows x 136 columns]

# %% [markdown]
# Теперь посмотрим на среднее значение признаков для каждой школы:

# %%
data_by_school.mean()
# Out:
# <ipython-input-34-86eeb72da5d5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_by_school.mean()
#               age      Medu      Fedu  traveltime  studytime  failures  \
# school
# GP      16.521490  2.802292  2.553009    1.386819   2.063037  0.318052
# MS      18.021739  2.347826  2.282609    1.913043   1.826087  0.456522
#
#           famrel  freetime     goout      Dalc      Walc    health  absences  \
# school
# GP      3.959885  3.223496  3.111748  1.444126  2.260745  3.575931  5.965616
# MS      3.826087  3.326087  3.086957  1.760870  2.521739  3.391304  3.760870
#
#                G1         G2         G3       alc
# school
# GP      10.939828  10.782235  10.489971  1.677446
# MS      10.673913  10.195652   9.847826  1.978261

# %% [markdown]
# Можно заметить, например, что в среднем до школы Mousinho da Silveira студентам нужно добираться дольше, чем до Gabriel Pereira. Интересно, что, несмотря на это, в среднем количество пропусков у них меньше.

# %% [markdown]
# ### Задания для самостоятельного решения

# %% [markdown]
# 1. Получите таблицу со студентами с четными номерами.
# 2. Получите таблицу со студентами, имеющими четное число пропусков.
# 3. Верно ли, что студенты, имеющие больше 10 пропусков, учатся хуже, чем остальные?
# 4. Как вы думаете, какие еще признаки могут повлиять на итоговую оценку? Найдите закономерности, аналогичные рассмотренным.
# 5. Как вы думаете, если при школе откроется общежитие, насколько актуально это будет для студентов математического класса?
# 6. Найдите в данных закономерности с помощью группировки.

# %% [markdown]
# Завдання 1
# Виведемо таблицю зі студентами, що мають парний номер

# %%
data[data.index % 2 == 0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# # Завдання 2
# Виведемо дані зі студентами, що мають парну кількість пропусків:

# %%
data[data['absences'] % 2 == 0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# # Завдання 3
# Перевіримо чи вірно, що студенти, що мають більше 10 пропусків навчаються гірше, ніж інші.
# Для цього виведемо середню підсумкову оцінку студентів, які мають більше 10 пропусків:

# %%
more_than_10_absences = data[data['absences'] > 10]['G3'].mean()
more_than_10_absences
# Out:
# 10.151515151515152

# %% [markdown]
# Та середню оцінку студентів, що мають менше або рівно, ніж 10 пропусків:

# %%
less_than_10_absences  = data[data['absences'] <= 10]['G3'].mean()
less_than_10_absences
# Out:
# 10.46808510638298

# %% [markdown]
# Порівнявши отримані значення

# %%
more_than_10_absences < less_than_10_absences
# Out:
# True

# %% [markdown]
# Ми отримаємо, що дане твердження є вірним

# %% [markdown]
# # Завдання 4
# Проведемо кореляційний аналіз стовпців таблиці

# %%
correlation = data.corr()['G3'].sort_values()
correlation
# Out:
# <ipython-input-40-91b327879be6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data.corr()['G3'].sort_values()
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# alc          -0.058679
# Dalc         -0.054660
# Walc         -0.051939
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %% [markdown]
# За даними результатами ми бачимо, що існують  слабкі позитивні кореляції між підсумковою оцінкою та освітою батьків (Medu та Fedu). Переглянемо середню оцінку студентів, батьки яких мають вищу освіту:

# %%
higher_edu = data[(data['Medu'] == 4) & (data['Fedu'] == 4 )]['G3'].mean()
higher_edu
# Out:
# 11.657142857142857

# %% [markdown]
# Та тих, у кого батьки не мають вищої освіти:

# %%
not_higher_edu = data[(data['Medu'] < 4) | (data['Fedu'] < 4)]['G3'].mean()
not_higher_edu
# Out:
# 10.147692307692308

# %% [markdown]
# Бачимо, що середня оцінка тих студентів, у кого батьки мають вищу освіту значно вища, ніж тих, у кого батьки не мають вищої освіти. е може вказувати на те, що батьки з вищою освітою можуть надавати більше академічної підтримки своїм дітям.

# %% [markdown]
# Відзначається негативна кореляція між підсумковою оцінкою та кількістю нескладених предметів у минулому (failures). Знайдемо середню оцінку тих студентів, які  мають  не більше одного незданого предмету

# %%
data[data['failures'] <= 1]['G3'].mean()
# Out:
# 10.820441988950277

# %% [markdown]
# Та середню оцінку студентів, які мають більше одного незданого предмету:

# %%
data[data['failures'] > 1]['G3'].mean()
# Out:
# 5.96969696969697

# %% [markdown]
# Cередній бал студентів, які мають не більше одного незданого предмета, очевидно вищий, ніж у студентів, які мають більше одного незданого предмета. Це може свідчити про те, що нездані предмети можуть негативно впливати на загальну успішність студента.

# %% [markdown]
# Маємо позитивну кореляцію між часом, витраченим на навчання (studytime) та підсумковою оцінкою. Знайдемо середній бал студентів, що витрачають більше 5 годин на навчання:

# %%
data[data['studytime'] >= 3]['G3'].mean()
# Out:
# 11.358695652173912

# %% [markdown]
# Та тих, хто витрачає менше 5 годин:

# %%
data[data['studytime'] < 3]['G3'].mean()
# Out:
# 10.128712871287128

# %% [markdown]
# Таким чином, час витрачений на навчання дещо впливає на покращення підсумкової оцінки. Хоча різниця в середньому балі між студентами, які витрачають більше 10 годин на навчання та менше 2 годин не є критичною (1,2 бала)

# %%
data[data['studytime'] == 4]['G3'].mean() - data[data['studytime'] == 1]['G3'].mean()
# Out:
# 1.211640211640212

# %% [markdown]
# І в цілому бачимо, що середня успішність тих, хто витрачає більше 10 годин дещо падає.

# %%
grouped = data.groupby('studytime')['G3'].mean()

grouped.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Час вивчення')
plt.ylabel('Середня оцінка')
plt.title('Середня оцінка в залежності від часу вивчення')
plt.show()

# %% [markdown]
# Бачимо негативну кореляцію між вживанням алкоголю та підсумковою оцінкою.
# Знайдемо середній бал студентів, які дуже часто вживають алкоголь

# %%
data[(data['Dalc'] == 5) & (data['Walc'] == 5)]['G3'].mean()
# Out:
# 10.666666666666666

# %% [markdown]
# Та студентів, які вживають його дуже рідко:

# %%
data[(data['Dalc'] == 1) & (data['Walc'] == 1)]['G3'].mean()
# Out:
# 10.806666666666667

# %% [markdown]
# Таким чином, різниця досить незначна. Подивимось чи дає більш значний ефект вживання алкоголю лише по буднях:

# %%
data[(data['Dalc'] == 5)]['G3'].mean()
# Out:
# 10.666666666666666

# %%
data[(data['Dalc'] == 1)]['G3'].mean()
# Out:
# 10.731884057971014

# %% [markdown]
# Як можемо помітити, різниця між середніми балами ще менша. Таким чином, можемо зробити висновок, що кількість вживаного алкоголю негативно впливає на успішність, але незначно.

# %% [markdown]
# Інші фактори, такі як вік (age), час, витрачений на дорогу до школи (traveltime), стан здоров’я (health),  відносини в сім’ї (famrel), вільний час після школи (freetime) мають менш виражену кореляцію з підсумковою оцінкою.

# %% [markdown]
# Крім того, на результати навчання можуть впливати і не числові дані. Переглянемо середні бали студентів, в залежності від школи:

# %%
data.groupby('school')['G3'].mean()
# Out:
# school
# GP    10.489971
# MS     9.847826
# Name: G3, dtype: float64

# %% [markdown]
# Бачимо, що учні школи Gabriel Pereira мають в середньому кращу успішність, ніж Mousinho da Silveira.

# %% [markdown]
# Існує думка, що учні в сільській місцевості навчаються дещо гірше, ніж учні з міста. Перевіримо це:

# %%
data.groupby('address')['G3'].mean()
# Out:
# address
# R     9.511364
# U    10.674267
# Name: G3, dtype: float64

# %% [markdown]
# Справді, можемо помітити, що успішність міських студентів в середньому вища.

# %% [markdown]
# Переглянемо середній бал студентів в залежності від опікуна

# %%
data.groupby('guardian')['G3'].mean()
# Out:
# guardian
# father    10.688889
# mother    10.483516
# other      9.062500
# Name: G3, dtype: float64

# %% [markdown]
# Таким чином, можемо побачити, що студенти, опікунами яких є рідні батьки мають вищий бал, ніж студенти без батьків.

# %% [markdown]
# Також позитивний вплив на середній бал має наявність інтернету:

# %%
data.groupby('internet')['G3'].mean()
# Out:
# internet
# no      9.409091
# yes    10.617021
# Name: G3, dtype: float64

# %% [markdown]
# # Завдання 5
# Знайдеемо кількість студентів, для яких дорога від дому до школи складає більше 1 год та проживають в місті  (будемо вважати, що в такому випадку студенти захочуть проживати у гуртожитку)

# %%
students_far_from_school = data[(data['address'] == 'U') & (data['traveltime'] == 4)].shape[0]
students_far_from_school
# Out:
# 3

# %% [markdown]
# Та знайдемо кількість студентів із сільської місцевості

# %%
students_in_rural = data[data['address'] == 'R'].shape[0]
students_in_rural
# Out:
# 88

# %% [markdown]
# Тоді кількість студентів, які будуть потребувати гуртожитку рівна

# %%
students_for_hostel = students_far_from_school + students_in_rural
students_for_hostel
# Out:
# 91

# %% [markdown]
# Ця кількість у відсотках від загальної кількості складає

# %%
(students_for_hostel / data.shape[0]) * 100
# Out:
# 23.037974683544306

# %% [markdown]
# На нашу думку, це досить значна частина студентів (майже четверта частина), тому відкриття гуртожитку було б актуальним.

# %% [markdown]
# # Завдання 6
# Знайдемо деякі закономірності:
#
#
# 1.   Знайдемо середній вік учнів за типом школи:

# %%
data.groupby('school')['age'].mean()
# Out:
# school
# GP    16.521490
# MS    18.021739
# Name: age, dtype: float64

# %% [markdown]
# Таким чином, можемо помітити, що учні Mousinho da Silveira в середньому на 1,5 роки старші, ніж учні Gabriel Pereira. Враховуючи, що ми встановили, що учні Mousinho da Silveira мають дещо кращі результати, ніж Gabriel Pereira, дослідимо також вплив  віку на успішність студентів:

# %%
data.groupby('age')['G3'].mean()
# Out:
# age
# 15    11.256098
# 16    11.028846
# 17    10.275510
# 18     9.548780
# 19     8.208333
# 20    14.000000
# 21     7.000000
# 22     8.000000
# Name: G3, dtype: float64

# %% [markdown]
# Таким чином, бачимо, що середній бал 20-річних студентів, якісно вирізняється на фоні інших, що може бути пов'язано з віковими особливостями когнітивного розвитку.

# %% [markdown]
# 2.  Знайдемо кількість студентів за статтю та типом школи та за статтю:

# %%
data.groupby(['school', 'sex']).size()
# Out:
# school  sex
# GP      F      183
#         M      166
# MS      F       25
#         M       21
# dtype: int64

# %% [markdown]
# Можемо побачити, що загальна кількість учнів Mousinho da Silveira значно менша, ніж кількість учнів Gabriel Pereira, що може поставити наш попередній висновок про кращу освіту в школі Mousinho da Silveira, оскільки об'єми вибірок для кожної школи значно відрізняються.

# %% [markdown]
# 3.  Середній час подорожі до школи за типом адреси:

# %%
data.groupby('address')['traveltime'].mean()
# Out:
# address
# R    1.875000
# U    1.325733
# Name: traveltime, dtype: float64

# %% [markdown]
# Можемо помітити, що учні як із сільської місцевості в середньому витрачають не значно більше часу на дорогу, ніж учні міської місцевості, що може свідчити про те, що дана сільська місцевість знаходиться не надто далеко від міста.

# %% [markdown]
# 4.   Кількість студентів, які отримують додаткову освіту, за типом школи:

# %%
data[data['schoolsup'] == 'yes'].groupby('school').size()
# Out:
# school
# GP    51
# dtype: int64

# %% [markdown]
# Можемо помітити, що додаткову освіту отримують тільки учні  Gabriel Pereira, що може свідчити як про невпевненість у знаннях учнів ці, які надає школа, так і про те, що учні цієї школи можуть бути більш амбіційними та мотивованими до саморозвитку.

# %% [markdown]
# 5. Знайдемо кількість студентів, які мають інтернет, за типом школи:

# %%
data.groupby(['address', 'internet']).size()
# Out:
# address  internet
# R        no           28
#          yes          60
# U        no           38
#          yes         269
# dtype: int64

# %% [markdown]
# Таким чином, бачимо що в міській місцевості набагато більший відсоток учнів має змогу користуватись інтернетом.

# %% [markdown]
# 6. Кількість студентів, які мають романтичні стосунки, за адресою та статтю:

# %%
romantic_students = data[data['romantic'] == 'yes'].groupby(['address', 'sex']).size()
total_students = data.groupby(['address', 'sex']).size()
percentage = (romantic_students / total_students) * 100

# %% [markdown]
# Знайдемо відсоткове відношення

# %%
percentage
# Out:
# address  sex
# R        F      29.545455
#          M      36.363636
# U        F      40.243902
#          M      25.874126
# dtype: float64

# %% [markdown]
# Таким чином, можемо помітити, що серед студентів чоловічої статі значно простіше вступають у романтичні відносини студенти з сільської місцевості, в той час як для жіночої статі - навпаки.

# %% [markdown]
# # Висновки:
# Виконуючи роботу ми отримали цінний досвід у використанні різних методів для аналізу даних.  використовуючи pandas для отримання таблиць зі студентами з парними номерами та студентами, які мають парну кількість пропусків ми засвоїли навички роботи з індексацію та фільтрацію в pandas. Навчилися застосовувати групування для пошуку закономірностей в даних, доослідили, як різні фактори, такі як кількість пропусків, можуть впливати на успішність навчання студентів. Це допомогло нам краще зрозуміти, як різні аспекти життя студента можуть впливати на їхню успішність.
